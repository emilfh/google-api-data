# %% [markdown]
# Import packages

# %%
import pandas as pd
import numpy as np
import gapandas4 as gp

import os

#from pandas import json_normalize
#import json

# %% [markdown]
# Properties for connections

# %%
property_id = "298727788"
credentials_json_path="/Users/emil/miniforge3/envs/googleapi/Notebooks/Analytics/client_secrets.json"

service_account = credentials_json_path

# %% [markdown]
# Get metadata

# %%
metadata = gp.get_metadata(service_account, property_id)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

dfMetadata = pd.DataFrame(metadata)

# %% [markdown]
# Dates to fetch data

# %%
start_date = "2023-05-01"
end_date="2023-05-20"

# %% [markdown]
# Batch-queries

# %%
# List of dimensions and metrics

# From analyticsreports

# dateList is all dimensions
dateList = ["date"]

# masterList is all metrics
masterList = ["totalUsers","newUsers","activeUsers","screenPageViews","sessions","engagedSessions",
              "userEngagementDuration","eventCount"]

# masterList2 is all metrics
masterList2 = ["organicGoogleSearchClicks","organicGoogleSearchImpressions",
               "organicGoogleSearchClickThroughRate","organicGoogleSearchAveragePosition"]

# List3 is all metrics
activityList = ["active28DayUsers","active7DayUsers","activeUsers","screenPageViews","sessions","engagedSessions",
              "userEngagementDuration","eventCount"]

# List4 is all metrics
loyaltyList = ["wauPerMau","dauPerMau","dauPerWau","screenPageViews","sessions","engagedSessions",
              "userEngagementDuration","eventCount"]

# Lists for each measure

# List of filenames to fill with measures below and use when writing df to .csv
dimensions = ["countryID","region","city","language","userAgeBracket","userGender",
             "brandingInterest","browser","deviceCategory","mobileDeviceBranding",
             "mobileDeviceModel","operatingSystem","platform","screenResolution",
             "firstUserDefaultChannelGroup","firstUserSource","sessionDefaultChannelGroup",
             "sessionSource","landingPage","eventName"]
queries_dims_metrics = []

for x in range(len(dimensions)):
    queries_dims_metrics.append(dateList + [dimensions[x]] + masterList)


'''
    

# Dictionary with position and dimensions
dimensionsDict = dict()

dimensionsDict= dict(dimensions = , filename = , country = "Norway")

for x in range(len(dimensions)):
    dimensionsDict[x] = dimensions[x]
    
dimensionsDict.keys()
dimensionsDict.values()

# Batch 1 - Lists

for j in (0,1,2,3,4):

    list[j] = [dimensionsDict[j]]
    dimensionsDict.update({dateList + list1 + masterList: }) = dateList + list[j] + masterList
    
    dateList + list1 + masterList
    

filename1 = str(dimensions[0])
 = [filename1]
listNames.append(dateList + list1 + masterList
                 
listNames = []
listNames.append(dateList + listNames[0] + masterList)


filename2 = str(dimensions[1])
list2 = [filename2]
list2 = dateList + list2 + masterList

filename3 = str(dimensions[2])
list3 = [filename3]
list3 = dateList + list3 + masterList

filename4 = str(dimensions[3])
list4 = [filename4]
list4 = dateList + list4 + masterList

filename5 = str(dimensions[4])
list5 = [filename5]
list5 = dateList + list5 + masterList

# Batch 2 - Lists
filename6 = "city"
userGenderList = ["userGender"]
userGender = dateList + userGenderList + masterList

filename7 = "city"
brandingInterestList = ["brandingInterest"]
brandingInterest = dateList + brandingInterestList + masterList

filename3 = "city"
browserList = ["browser"]
browser = dateList + browserList + masterList

filename3 = "city"
deviceCategoryList = ["deviceCategory"]
deviceCategory = dateList + deviceCategoryList + masterList

filename3 = "city"
mobileDeviceBrandingList = ["mobileDeviceBranding"]
mobileDeviceBranding = dateList + mobileDeviceBrandingList + masterList

#notset ; appversion deviceModel mobiledevicemarketingname 
# not needed: streamID and Name (only got 1 value) language + languageCode, in other list
# operatingSystemVersion, operatingSystemWithVersion not needed I dont think

# Batch 3 - Lists
filename3 = "city"
mobileDeviceModelList = ["mobileDeviceModel"]
mobileDeviceModel = dateList + mobileDeviceModelList + masterList

filename3 = "city"
operatingSystemList = ["operatingSystem"]
operatingSystem = dateList + operatingSystemList + masterList

filename3 = "city"
platformList = ["platform"]
platform = dateList + platformList + masterList

filename3 = "city"
platformDeviceCategoryList = ["platformDeviceCategory"]
platformDeviceCategory = dateList + platformDeviceCategoryList + masterList

filename3 = "city"
screenResolutionList = ["screenResolution"]
screenResolution = dateList + screenResolutionList + masterList

#DEVICE CATEGORY, PLATFORM and PLATFORMDEVICECATEGORY not needed all 3.

# Batch 4 - Lists

filename3 = "city"
firstUserDefaultChannelGroupList = ["firstUserDefaultChannelGroup"]
firstUserDefaultChannelGroup = dateList + firstUserDefaultChannelGroupList + masterList

filename3 = "city"
firstUserSourceList = ["firstUserSource"]
firstUserSource = dateList + firstUserSourceList + masterList

filename3 = "city"
sessionDefaultChannelGroupList = ["sessionDefaultChannelGroup"]
sessionDefaultChannelGroup = dateList + sessionDefaultChannelGroupList + masterList

filename3 = "city"
sessionSourceList = ["sessionSource"]
sessionSource = dateList + sessionSourceList + masterList

# Batch 5 - Lists

# max 10 lines in request so have to merge two requests.

filename3 = "city"
landingPageList = ["landingPage"]
landingPage = dateList + landingPageList + masterList

filename3 = "city"
eventNameList = ["eventName"]
eventName = dateList + eventNameList + masterList

filename3 = "city"
activity = dateList + activityList 

filename3 = "city"
loyalty = dateList + loyaltyList


#linkUrlList = ["linkUrl"]
#linkUrl = ["date"] + linkUrlList + masterList2 + masterList



# firstUserManualTerm, firstUserSourcePlatform NOTSET
# firstUserCampaignName and ID not needed since got DefaultChannelGroup
# All Ad-dimensions seems to be empty, same for 360.

#"sessionGoogleAdsAdNetworkType",
#"sessionSa360EngineAccountType","sessionSa360Source"]

# NOTSET "firstUserGoogleAdsAdNetworkType","firstUserGoogleAdsCampaignType"

# Fill list with filenames
fileNames = [eval('filename%d' %i) for i in range(1,3)]
'''
# Out:
# '\n    \n\n# Dictionary with position and dimensions\ndimensionsDict = dict()\n\ndimensionsDict= dict(dimensions = , filename = , country = "Norway")\n\nfor x in range(len(dimensions)):\n    dimensionsDict[x] = dimensions[x]\n    \ndimensionsDict.keys()\ndimensionsDict.values()\n\n# Batch 1 - Lists\n\nfor j in (0,1,2,3,4):\n\n    list[j] = [dimensionsDict[j]]\n    dimensionsDict.update({dateList + list1 + masterList: }) = dateList + list[j] + masterList\n    \n    dateList + list1 + masterList\n    \n\nfilename1 = str(dimensions[0])\n = [filename1]\nlistNames.append(dateList + list1 + masterList\n                 \nlistNames = []\nlistNames.append(dateList + listNames[0] + masterList)\n\n\nfilename2 = str(dimensions[1])\nlist2 = [filename2]\nlist2 = dateList + list2 + masterList\n\nfilename3 = str(dimensions[2])\nlist3 = [filename3]\nlist3 = dateList + list3 + masterList\n\nfilename4 = str(dimensions[3])\nlist4 = [filename4]\nlist4 = dateList + list4 + masterList\n\nfilename5 = str(dimensions[4])\nlist5 = [filename5]\nlist5 = dateList + list5 + masterList\n\n# Batch 2 - Lists\nfilename6 = "city"\nuserGenderList = ["userGender"]\nuserGender = dateList + userGenderList + masterList\n\nfilename7 = "city"\nbrandingInterestList = ["brandingInterest"]\nbrandingInterest = dateList + brandingInterestList + masterList\n\nfilename3 = "city"\nbrowserList = ["browser"]\nbrowser = dateList + browserList + masterList\n\nfilename3 = "city"\ndeviceCategoryList = ["deviceCategory"]\ndeviceCategory = dateList + deviceCategoryList + masterList\n\nfilename3 = "city"\nmobileDeviceBrandingList = ["mobileDeviceBranding"]\nmobileDeviceBranding = dateList + mobileDeviceBrandingList + masterList\n\n#notset ; appversion deviceModel mobiledevicemarketingname \n# not needed: streamID and Name (only got 1 value) language + languageCode, in other list\n# operatingSystemVersion, operatingSystemWithVersion not needed I dont think\n\n# Batch 3 - Lists\nfilename3 = "city"\nmobileDeviceModelList = ["mobileDeviceModel"]\nmobileDeviceModel = dateList + mobileDeviceModelList + masterList\n\nfilename3 = "city"\noperatingSystemList = ["operatingSystem"]\noperatingSystem = dateList + operatingSystemList + masterList\n\nfilename3 = "city"\nplatformList = ["platform"]\nplatform = dateList + platformList + masterList\n\nfilename3 = "city"\nplatformDeviceCategoryList = ["platformDeviceCategory"]\nplatformDeviceCategory = dateList + platformDeviceCategoryList + masterList\n\nfilename3 = "city"\nscreenResolutionList = ["screenResolution"]\nscreenResolution = dateList + screenResolutionList + masterList\n\n#DEVICE CATEGORY, PLATFORM and PLATFORMDEVICECATEGORY not needed all 3.\n\n# Batch 4 - Lists\n\nfilename3 = "city"\nfirstUserDefaultChannelGroupList = ["firstUserDefaultChannelGroup"]\nfirstUserDefaultChannelGroup = dateList + firstUserDefaultChannelGroupList + masterList\n\nfilename3 = "city"\nfirstUserSourceList = ["firstUserSource"]\nfirstUserSource = dateList + firstUserSourceList + masterList\n\nfilename3 = "city"\nsessionDefaultChannelGroupList = ["sessionDefaultChannelGroup"]\nsessionDefaultChannelGroup = dateList + sessionDefaultChannelGroupList + masterList\n\nfilename3 = "city"\nsessionSourceList = ["sessionSource"]\nsessionSource = dateList + sessionSourceList + masterList\n\n# Batch 5 - Lists\n\n# max 10 lines in request so have to merge two requests.\n\nfilename3 = "city"\nlandingPageList = ["landingPage"]\nlandingPage = dateList + landingPageList + masterList\n\nfilename3 = "city"\neventNameList = ["eventName"]\neventName = dateList + eventNameList + masterList\n\nfilename3 = "city"\nactivity = dateList + activityList \n\nfilename3 = "city"\nloyalty = dateList + loyaltyList\n\n\n#linkUrlList = ["linkUrl"]\n#linkUrl = ["date"] + linkUrlList + masterList2 + masterList\n\n\n\n# firstUserManualTerm, firstUserSourcePlatform NOTSET\n# firstUserCampaignName and ID not needed since got DefaultChannelGroup\n# All Ad-dimensions seems to be empty, same for 360.\n\n#"ses ...

# %%
dimensions = ["countryID","region","city","language","userAgeBracket"]

dimensionsDict = dict()

for x in range(len(dimensions)):
    dimensionsDict[x] = dimensions[x]

# %%
dimensionsDict
# Out:
# {0: 'countryID', 1: 'region', 2: 'city', 3: 'language', 4: 'userAgeBracket'}

# %%
filnamesNumber = list(range(0, len(dimensions)))

# %%
dimensions = ["countryID","region","city","language","userAgeBracket"]
filenames = list(range(0, len(dimensions)))

# %%
filenames
# Out:
# [0, 1, 2, 3, 4]

# %%
testaaar = [dimensions[0]]
listNames = []
listNames.append(dateList + testaaar + masterList)

# %%
[dimensions[1]]
# Out:
# ['region']

# %%
dimensions = ["countryID","region","city","language","userAgeBracket"]
                 
listNamesET = []
listNamesET.append(dateList + [dimensions[0]] + masterList)

# %%
listNamesET.append(dateList + [dimensions[1]] + masterList)

# %%
listNamesET[0][0]
# Out:
# 'date'

# %%
query_dim_metric = []

for x in range(len(dimensions)):
    query_dim_metric.append(dateList + [dimensions[x]] + masterList)

# %%
queries_dims_metrics
# Out:
# [['date',
#   'countryID',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'region',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'city',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'language',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'userAgeBracket',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'userGender',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'brandingInterest',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'browser',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'deviceCategory',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'mobileDeviceBranding',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'mobileDeviceModel',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'operatingSystem',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'platform',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'screenResolution',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'firstUserDefaultChannelGroup',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'firstUserSource',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'sessionDefaultChannelGroup',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'sessionSource',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'landingPage',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount'],
#  ['date',
#   'eventName',
#   'totalUsers',
#   'newUsers',
#   'activeUsers',
#   'screenPageViews',
#   'sessions',
#   'engagedSessions',
#   'userEngagementDuration',
#   'eventCount']]

# %%
#TEST

# Batch 0 - Request
batch_report_request_test = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[0][0]),
                gp.Dimension(name=queries_dims_metrics[0][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[0][2]),
                gp.Metric(name=queries_dims_metrics[0][3]),
                gp.Metric(name=queries_dims_metrics[0][4]),
                gp.Metric(name=queries_dims_metrics[0][5]),
                gp.Metric(name=queries_dims_metrics[0][6]),
                gp.Metric(name=queries_dims_metrics[0][7]),
                gp.Metric(name=queries_dims_metrics[0][8]),
                gp.Metric(name=queries_dims_metrics[0][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[1][0]),
                gp.Dimension(name=queries_dims_metrics[1][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[1][2]),
                gp.Metric(name=queries_dims_metrics[1][3]),
                gp.Metric(name=queries_dims_metrics[1][4]),
                gp.Metric(name=queries_dims_metrics[1][5]),
                gp.Metric(name=queries_dims_metrics[1][6]),
                gp.Metric(name=queries_dims_metrics[1][7]),
                gp.Metric(name=queries_dims_metrics[1][8]),
                gp.Metric(name=queries_dims_metrics[1][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[2][0]),
                gp.Dimension(name=queries_dims_metrics[2][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[2][2]),
                gp.Metric(name=queries_dims_metrics[2][3]),
                gp.Metric(name=queries_dims_metrics[2][4]),
                gp.Metric(name=queries_dims_metrics[2][5]),
                gp.Metric(name=queries_dims_metrics[2][6]),
                gp.Metric(name=queries_dims_metrics[2][7]),
                gp.Metric(name=queries_dims_metrics[2][8]),
                gp.Metric(name=queries_dims_metrics[2][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[3][0]),
                gp.Dimension(name=queries_dims_metrics[3][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[3][2]),
                gp.Metric(name=queries_dims_metrics[3][3]),
                gp.Metric(name=queries_dims_metrics[3][4]),
                gp.Metric(name=queries_dims_metrics[3][5]),
                gp.Metric(name=queries_dims_metrics[3][6]),
                gp.Metric(name=queries_dims_metrics[3][7]),
                gp.Metric(name=queries_dims_metrics[3][8]),
                gp.Metric(name=queries_dims_metrics[3][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
                
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[4][0]),
                gp.Dimension(name=queries_dims_metrics[4][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[4][2]),
                gp.Metric(name=queries_dims_metrics[4][3]),
                gp.Metric(name=queries_dims_metrics[4][4]),
                gp.Metric(name=queries_dims_metrics[4][5]),
                gp.Metric(name=queries_dims_metrics[4][6]),
                gp.Metric(name=queries_dims_metrics[4][7]),
                gp.Metric(name=queries_dims_metrics[4][8]),
                gp.Metric(name=queries_dims_metrics[4][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
#TEST

# Batch 1 - Request
batch_report_request_test = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[5][0]),
                gp.Dimension(name=queries_dims_metrics[5][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[5][2]),
                gp.Metric(name=queries_dims_metrics[5][3]),
                gp.Metric(name=queries_dims_metrics[5][4]),
                gp.Metric(name=queries_dims_metrics[5][5]),
                gp.Metric(name=queries_dims_metrics[5][6]),
                gp.Metric(name=queries_dims_metrics[5][7]),
                gp.Metric(name=queries_dims_metrics[5][8]),
                gp.Metric(name=queries_dims_metrics[5][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[6][0]),
                gp.Dimension(name=queries_dims_metrics[6][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[6][2]),
                gp.Metric(name=queries_dims_metrics[6][3]),
                gp.Metric(name=queries_dims_metrics[6][4]),
                gp.Metric(name=queries_dims_metrics[6][5]),
                gp.Metric(name=queries_dims_metrics[6][6]),
                gp.Metric(name=queries_dims_metrics[6][7]),
                gp.Metric(name=queries_dims_metrics[6][8]),
                gp.Metric(name=queries_dims_metrics[6][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[7][0]),
                gp.Dimension(name=queries_dims_metrics[7][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[7][2]),
                gp.Metric(name=queries_dims_metrics[7][3]),
                gp.Metric(name=queries_dims_metrics[7][4]),
                gp.Metric(name=queries_dims_metrics[7][5]),
                gp.Metric(name=queries_dims_metrics[7][6]),
                gp.Metric(name=queries_dims_metrics[7][7]),
                gp.Metric(name=queries_dims_metrics[7][8]),
                gp.Metric(name=queries_dims_metrics[7][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[8][0]),
                gp.Dimension(name=queries_dims_metrics[8][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[8][2]),
                gp.Metric(name=queries_dims_metrics[8][3]),
                gp.Metric(name=queries_dims_metrics[8][4]),
                gp.Metric(name=queries_dims_metrics[8][5]),
                gp.Metric(name=queries_dims_metrics[8][6]),
                gp.Metric(name=queries_dims_metrics[8][7]),
                gp.Metric(name=queries_dims_metrics[8][8]),
                gp.Metric(name=queries_dims_metrics[8][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
                
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[9][0]),
                gp.Dimension(name=queries_dims_metrics[9][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[9][2]),
                gp.Metric(name=queries_dims_metrics[9][3]),
                gp.Metric(name=queries_dims_metrics[9][4]),
                gp.Metric(name=queries_dims_metrics[9][5]),
                gp.Metric(name=queries_dims_metrics[9][6]),
                gp.Metric(name=queries_dims_metrics[9][7]),
                gp.Metric(name=queries_dims_metrics[9][8]),
                gp.Metric(name=queries_dims_metrics[9][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
#TEST

# Batch 2 - Request
batch_report_request_test = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[0][0]),
                gp.Dimension(name=queries_dims_metrics[0][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[0][2]),
                gp.Metric(name=queries_dims_metrics[0][3]),
                gp.Metric(name=queries_dims_metrics[0][4]),
                gp.Metric(name=queries_dims_metrics[0][5]),
                gp.Metric(name=queries_dims_metrics[0][6]),
                gp.Metric(name=queries_dims_metrics[0][7]),
                gp.Metric(name=queries_dims_metrics[0][8]),
                gp.Metric(name=queries_dims_metrics[0][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[1][0]),
                gp.Dimension(name=queries_dims_metrics[1][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[1][2]),
                gp.Metric(name=queries_dims_metrics[1][3]),
                gp.Metric(name=queries_dims_metrics[1][4]),
                gp.Metric(name=queries_dims_metrics[1][5]),
                gp.Metric(name=queries_dims_metrics[1][6]),
                gp.Metric(name=queries_dims_metrics[1][7]),
                gp.Metric(name=queries_dims_metrics[1][8]),
                gp.Metric(name=queries_dims_metrics[1][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[2][0]),
                gp.Dimension(name=queries_dims_metrics[2][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[2][2]),
                gp.Metric(name=queries_dims_metrics[2][3]),
                gp.Metric(name=queries_dims_metrics[2][4]),
                gp.Metric(name=queries_dims_metrics[2][5]),
                gp.Metric(name=queries_dims_metrics[2][6]),
                gp.Metric(name=queries_dims_metrics[2][7]),
                gp.Metric(name=queries_dims_metrics[2][8]),
                gp.Metric(name=queries_dims_metrics[2][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[3][0]),
                gp.Dimension(name=queries_dims_metrics[3][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[3][2]),
                gp.Metric(name=queries_dims_metrics[3][3]),
                gp.Metric(name=queries_dims_metrics[3][4]),
                gp.Metric(name=queries_dims_metrics[3][5]),
                gp.Metric(name=queries_dims_metrics[3][6]),
                gp.Metric(name=queries_dims_metrics[3][7]),
                gp.Metric(name=queries_dims_metrics[3][8]),
                gp.Metric(name=queries_dims_metrics[3][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
                
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[4][0]),
                gp.Dimension(name=queries_dims_metrics[4][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[4][2]),
                gp.Metric(name=queries_dims_metrics[4][3]),
                gp.Metric(name=queries_dims_metrics[4][4]),
                gp.Metric(name=queries_dims_metrics[4][5]),
                gp.Metric(name=queries_dims_metrics[4][6]),
                gp.Metric(name=queries_dims_metrics[4][7]),
                gp.Metric(name=queries_dims_metrics[4][8]),
                gp.Metric(name=queries_dims_metrics[4][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
#TEST

# Batch 3 - Request
batch_report_request_test = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[0][0]),
                gp.Dimension(name=queries_dims_metrics[0][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[0][2]),
                gp.Metric(name=queries_dims_metrics[0][3]),
                gp.Metric(name=queries_dims_metrics[0][4]),
                gp.Metric(name=queries_dims_metrics[0][5]),
                gp.Metric(name=queries_dims_metrics[0][6]),
                gp.Metric(name=queries_dims_metrics[0][7]),
                gp.Metric(name=queries_dims_metrics[0][8]),
                gp.Metric(name=queries_dims_metrics[0][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[1][0]),
                gp.Dimension(name=queries_dims_metrics[1][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[1][2]),
                gp.Metric(name=queries_dims_metrics[1][3]),
                gp.Metric(name=queries_dims_metrics[1][4]),
                gp.Metric(name=queries_dims_metrics[1][5]),
                gp.Metric(name=queries_dims_metrics[1][6]),
                gp.Metric(name=queries_dims_metrics[1][7]),
                gp.Metric(name=queries_dims_metrics[1][8]),
                gp.Metric(name=queries_dims_metrics[1][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[2][0]),
                gp.Dimension(name=queries_dims_metrics[2][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[2][2]),
                gp.Metric(name=queries_dims_metrics[2][3]),
                gp.Metric(name=queries_dims_metrics[2][4]),
                gp.Metric(name=queries_dims_metrics[2][5]),
                gp.Metric(name=queries_dims_metrics[2][6]),
                gp.Metric(name=queries_dims_metrics[2][7]),
                gp.Metric(name=queries_dims_metrics[2][8]),
                gp.Metric(name=queries_dims_metrics[2][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[3][0]),
                gp.Dimension(name=queries_dims_metrics[3][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[3][2]),
                gp.Metric(name=queries_dims_metrics[3][3]),
                gp.Metric(name=queries_dims_metrics[3][4]),
                gp.Metric(name=queries_dims_metrics[3][5]),
                gp.Metric(name=queries_dims_metrics[3][6]),
                gp.Metric(name=queries_dims_metrics[3][7]),
                gp.Metric(name=queries_dims_metrics[3][8]),
                gp.Metric(name=queries_dims_metrics[3][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
                
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[4][0]),
                gp.Dimension(name=queries_dims_metrics[4][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[4][2]),
                gp.Metric(name=queries_dims_metrics[4][3]),
                gp.Metric(name=queries_dims_metrics[4][4]),
                gp.Metric(name=queries_dims_metrics[4][5]),
                gp.Metric(name=queries_dims_metrics[4][6]),
                gp.Metric(name=queries_dims_metrics[4][7]),
                gp.Metric(name=queries_dims_metrics[4][8]),
                gp.Metric(name=queries_dims_metrics[4][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
#TEST

# Batch 4 - Request
batch_report_request_test = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[0][0]),
                gp.Dimension(name=queries_dims_metrics[0][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[0][2]),
                gp.Metric(name=queries_dims_metrics[0][3]),
                gp.Metric(name=queries_dims_metrics[0][4]),
                gp.Metric(name=queries_dims_metrics[0][5]),
                gp.Metric(name=queries_dims_metrics[0][6]),
                gp.Metric(name=queries_dims_metrics[0][7]),
                gp.Metric(name=queries_dims_metrics[0][8]),
                gp.Metric(name=queries_dims_metrics[0][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[1][0]),
                gp.Dimension(name=queries_dims_metrics[1][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[1][2]),
                gp.Metric(name=queries_dims_metrics[1][3]),
                gp.Metric(name=queries_dims_metrics[1][4]),
                gp.Metric(name=queries_dims_metrics[1][5]),
                gp.Metric(name=queries_dims_metrics[1][6]),
                gp.Metric(name=queries_dims_metrics[1][7]),
                gp.Metric(name=queries_dims_metrics[1][8]),
                gp.Metric(name=queries_dims_metrics[1][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[2][0]),
                gp.Dimension(name=queries_dims_metrics[2][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[2][2]),
                gp.Metric(name=queries_dims_metrics[2][3]),
                gp.Metric(name=queries_dims_metrics[2][4]),
                gp.Metric(name=queries_dims_metrics[2][5]),
                gp.Metric(name=queries_dims_metrics[2][6]),
                gp.Metric(name=queries_dims_metrics[2][7]),
                gp.Metric(name=queries_dims_metrics[2][8]),
                gp.Metric(name=queries_dims_metrics[2][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[3][0]),
                gp.Dimension(name=queries_dims_metrics[3][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[3][2]),
                gp.Metric(name=queries_dims_metrics[3][3]),
                gp.Metric(name=queries_dims_metrics[3][4]),
                gp.Metric(name=queries_dims_metrics[3][5]),
                gp.Metric(name=queries_dims_metrics[3][6]),
                gp.Metric(name=queries_dims_metrics[3][7]),
                gp.Metric(name=queries_dims_metrics[3][8]),
                gp.Metric(name=queries_dims_metrics[3][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
                
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=queries_dims_metrics[4][0]),
                gp.Dimension(name=queries_dims_metrics[4][1]),
            ],
            metrics=[
                gp.Metric(name=queries_dims_metrics[4][2]),
                gp.Metric(name=queries_dims_metrics[4][3]),
                gp.Metric(name=queries_dims_metrics[4][4]),
                gp.Metric(name=queries_dims_metrics[4][5]),
                gp.Metric(name=queries_dims_metrics[4][6]),
                gp.Metric(name=queries_dims_metrics[4][7]),
                gp.Metric(name=queries_dims_metrics[4][8]),
                gp.Metric(name=queries_dims_metrics[4][9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
df_test = gp.query(service_account, batch_report_request_test, report_type="batch_report")

# %%
for n in range(len(df_test)):
    df_test[n]['date'] = pd.to_datetime(df_test[n]['date'])

# %%
for m in range(0,5):
    df_test[m] = df_test[m].sort_values(queries_dims_metrics[m], ascending=True)

# %%
df_test[2]
# Out:
#            date                           city totalUsers newUsers
# 43   2023-05-01                      (not set)         12       11  \
# 499  2023-05-01                         Arjang          1        0
# 500  2023-05-01                          Asele          1        1
# 501  2023-05-01                        Ashburn          1        0
# 502  2023-05-01                       Borlange          1        1
# 503  2023-05-01                          Ekero          1        1
# 504  2023-05-01                       Fagersta          1        1
# 505  2023-05-01                     Fargelanda          1        1
# 506  2023-05-01                       Finspang          1        0
# 507  2023-05-01                     Freienbach          1        1
# 508  2023-05-01                          Gavle          1        1
# 49   2023-05-01                     Gothenburg         11        9
# 509  2023-05-01                        Hagfors          1        1
# 275  2023-05-01                    Helsingborg          2        1
# 510  2023-05-01                       Huddinge          1        1
# 276  2023-05-01                      Jonkoping          2        2
# 511  2023-05-01                     Karlskrona          1        1
# 512  2023-05-01                       Karlstad          1        1
# 277  2023-05-01                       Kramfors          2        0
# 513  2023-05-01                     Kungsbacka          1        0
# 514  2023-05-01                         Lisbon          1        1
# 515  2023-05-01                        Ludvika          1        1
# 516  2023-05-01                         Madrid          1        1
# 88   2023-05-01                          Malmo          5        4
# 517  2023-05-01                         Marsta          1        0
# 165  2023-05-01                     Norrkoping          3        2
# 518  2023-05-01                        Ockelbo          1        1
# 519  2023-05-01                   Ornskoldsvik          1        1
# 520  2023-05-01                          Paris          1        1
# 521  2023-05-01                       Partille          1        1
# 278  2023-05-01                  Port Harcourt          2        1
# 522  2023-05-01                        Sharjah          1        0
# 279  2023-05-01                          Solna          2        2
# 15   2023-05-01                      Stockholm         42       41
# 523  2023-05-01                       Storuman          1        0
# 280  2023-05-01                      Strangnas          2        2
# 524  2023-05-01                     Sundbyberg          1        1
# 525  2023-05-01                      Sundsvall          1        0
# 281  2023-05-01                         Svalov          2        2
# 282  2023-05-01                     Svenljunga          2        1
# 166  2023-05-01                           Taby          3        3
# 1163                      0          3
# 1164                    446         14
# 1165                      0          3
# 478                     352          4
# 1166                    333          4
# 479                     245         19
# 1167                      0          3
# 1168                      6          5
# 261                     206         10
# 1169                      0          2
# 1170                     96          4
# 1171                     57          4
# 480                     112          7
# 1172                     40          4
# 1173                    161          4
# 1174                      0          2
# 1175                     40          4
# 1176                      0          3
# 1177                      4          3
# 1178                    298          6
# 18                     2304        140
# 481                      95          5
# 1179                    150          5
# 482                      30          7
# 1180                     16          6
# 1181                      0          2
# 1182                      0          3
# 262                     116         14
# 42                      280         49
# 263                     237          8
# 483                      67          7
# 1183                     42          1
# 264                       0         10
# 1184                      0          2
# 1185                    111          7
# 484                     292          9
# 1186                    186          4
# 485                     148         10
# 1187                      0          3
# 32                     1618         70
# 265                     104         13
# 266                     854         35
# 267                      29         12
# 1188                      3          3
# 110                     203         17
# 486                      76          9
# 1189                      0          3
# 1190                    110          1
# 1191                     16          4
# 1192                     93          7
# 73                      230         27
# 85                      162         14
# 1193                     18          4
# 111                     141         18
# 487                      17          7
# 1194                     72          4
# 1195                     78          5
# 1196                      0          5
# 162                       0         10
# 1197                     30          4
# 1198                     24          3
# 1199                     76          3
# 268                     209         14
# 1200                     55          4
# 1201                      0          3
# 488                       3          8
# 1202                      0          3
# 1203                     91          4
# 12                     2791        232
# 269                      23          9
# 489                       5          7
# 1204                    247          8
# 1205                      0          3
# 1206                     17          4
# 490                     198         11
# 491                      15          7
# 1207                      0          2
# 1208                      0          3
# 34                      985         70
# 1209                      0          3
# 270                     165         13
# 1210                      1          3
# 1211                      0          3
# 1212                      0          3
# 492                     430         23
# 1213                     13          4
# 1214                      0          5
# 1215                     86          4
# 493                     140          5
# 1216                    141          5
# 1217                    117          4
# 1218                    182          5
# 1219                      0          3
# 66                      128         26
# 1220                     23          4
# 271                     152         13
# 494                      58          9
# 272                      87         12
# 1221                      0          3
# 1222                      0          3
# 495                     248         14
# 496                      81          8
# 1223                    197          1
# 1224                      0          3
# 1225                      0          3
# 163                     173         15
# 86                      448         30
# 1226                     65          1
# 1227                    231          1
# 1228                      0          2
# 164                     311         12
# 1229                      0          4
# 1230                      0          3
# 1231                      0          3
# 1232                      0          3
# 1233                      4          4
# 497                     139          7
# 1234                     64          6
# 1235                    141          4
# 1236                    183          5
# 17                     2118        169
# 1237                      0          3
# 498                      81          5
# 1238                    155          4
# 1239                    192          4
# 1240                      0          3
# 1241                      0          3
# 1242                    432          4
# 1243                      0          3
# 87                      277         23
# 273                     391         27
# 274                     180         11
# 1244                      6          4

# %%
# Batch 1 - Request
batch_report_request1 = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=countryID[0]),
                gp.Dimension(name=countryID[1]),
            ],
            metrics=[
                gp.Metric(name=countryID[2]),
                gp.Metric(name=countryID[3]),
                gp.Metric(name=countryID[4]),
                gp.Metric(name=countryID[5]),
                gp.Metric(name=countryID[6]),
                gp.Metric(name=countryID[7]),
                gp.Metric(name=countryID[8]),
                gp.Metric(name=countryID[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=region[0]),
                gp.Dimension(name=region[1]),
            ],
            metrics=[
                gp.Metric(name=region[2]),
                gp.Metric(name=region[3]),
                gp.Metric(name=region[4]),
                gp.Metric(name=region[5]),
                gp.Metric(name=region[6]),
                gp.Metric(name=region[7]),
                gp.Metric(name=region[8]),
                gp.Metric(name=region[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=city[0]),
                gp.Dimension(name=city[1]),
            ],
            metrics=[
                gp.Metric(name=city[2]),
                gp.Metric(name=city[3]),
                gp.Metric(name=city[4]),
                gp.Metric(name=city[5]),
                gp.Metric(name=city[6]),
                gp.Metric(name=city[7]),
                gp.Metric(name=city[8]),
                gp.Metric(name=city[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=language[0]),
                gp.Dimension(name=language[1]),
            ],
            metrics=[
                gp.Metric(name=language[2]),
                gp.Metric(name=language[3]),
                gp.Metric(name=language[4]),
                gp.Metric(name=language[5]),
                gp.Metric(name=language[6]),
                gp.Metric(name=language[7]),
                gp.Metric(name=language[8]),
                gp.Metric(name=language[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
                
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=userAgeBracket[0]),
                gp.Dimension(name=userAgeBracket[1]),
            ],
            metrics=[
                gp.Metric(name=userAgeBracket[2]),
                gp.Metric(name=userAgeBracket[3]),
                gp.Metric(name=userAgeBracket[4]),
                gp.Metric(name=userAgeBracket[5]),
                gp.Metric(name=userAgeBracket[6]),
                gp.Metric(name=userAgeBracket[7]),
                gp.Metric(name=userAgeBracket[8]),
                gp.Metric(name=userAgeBracket[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
# Batch 2 - Request
batch_report_request2 = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=userGender[0]),
                gp.Dimension(name=userGender[1]),
            ],
            metrics=[
                gp.Metric(name=userGender[2]),
                gp.Metric(name=userGender[3]),
                gp.Metric(name=userGender[4]),
                gp.Metric(name=userGender[5]),
                gp.Metric(name=userGender[6]),
                gp.Metric(name=userGender[7]),
                gp.Metric(name=userGender[8]),
                gp.Metric(name=userGender[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=brandingInterest[0]),
                gp.Dimension(name=brandingInterest[1]),
            ],
            metrics=[
                gp.Metric(name=brandingInterest[2]),
                gp.Metric(name=brandingInterest[3]),
                gp.Metric(name=brandingInterest[4]),
                gp.Metric(name=brandingInterest[5]),
                gp.Metric(name=brandingInterest[6]),
                gp.Metric(name=brandingInterest[7]),
                gp.Metric(name=brandingInterest[8]),
                gp.Metric(name=brandingInterest[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=browser[0]),
                gp.Dimension(name=browser[1]),
            ],
            metrics=[
                gp.Metric(name=browser[2]),
                gp.Metric(name=browser[3]),
                gp.Metric(name=browser[4]),
                gp.Metric(name=browser[5]),
                gp.Metric(name=browser[6]),
                gp.Metric(name=browser[7]),
                gp.Metric(name=browser[8]),
                gp.Metric(name=browser[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=deviceCategory[0]),
                gp.Dimension(name=deviceCategory[1]),
            ],
            metrics=[
                gp.Metric(name=deviceCategory[2]),
                gp.Metric(name=deviceCategory[3]),
                gp.Metric(name=deviceCategory[4]),
                gp.Metric(name=deviceCategory[5]),
                gp.Metric(name=deviceCategory[6]),
                gp.Metric(name=deviceCategory[7]),
                gp.Metric(name=deviceCategory[8]),
                gp.Metric(name=deviceCategory[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=mobileDeviceBranding[0]),
                gp.Dimension(name=mobileDeviceBranding[1]),
            ],
            metrics=[
                gp.Metric(name=mobileDeviceBranding[2]),
                gp.Metric(name=mobileDeviceBranding[3]),
                gp.Metric(name=mobileDeviceBranding[4]),
                gp.Metric(name=mobileDeviceBranding[5]),
                gp.Metric(name=mobileDeviceBranding[6]),
                gp.Metric(name=mobileDeviceBranding[7]),
                gp.Metric(name=mobileDeviceBranding[8]),
                gp.Metric(name=mobileDeviceBranding[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
         
    ]
)

# %%
# Batch 3 - Request
batch_report_request3 = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=mobileDeviceModel[0]),
                gp.Dimension(name=mobileDeviceModel[1]),
            ],
            metrics=[
                gp.Metric(name=mobileDeviceModel[2]),
                gp.Metric(name=mobileDeviceModel[3]),
                gp.Metric(name=mobileDeviceModel[4]),
                gp.Metric(name=mobileDeviceModel[5]),
                gp.Metric(name=mobileDeviceModel[6]),
                gp.Metric(name=mobileDeviceModel[7]),
                gp.Metric(name=mobileDeviceModel[8]),
                gp.Metric(name=mobileDeviceModel[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=operatingSystem[0]),
                gp.Dimension(name=operatingSystem[1]),
            ],
            metrics=[
                gp.Metric(name=operatingSystem[2]),
                gp.Metric(name=operatingSystem[3]),
                gp.Metric(name=operatingSystem[4]),
                gp.Metric(name=operatingSystem[5]),
                gp.Metric(name=operatingSystem[6]),
                gp.Metric(name=operatingSystem[7]),
                gp.Metric(name=operatingSystem[8]),
                gp.Metric(name=operatingSystem[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=platform[0]),
                gp.Dimension(name=platform[1]),
            ],
            metrics=[
                gp.Metric(name=platform[2]),
                gp.Metric(name=platform[3]),
                gp.Metric(name=platform[4]),
                gp.Metric(name=platform[5]),
                gp.Metric(name=platform[6]),
                gp.Metric(name=platform[7]),
                gp.Metric(name=platform[8]),
                gp.Metric(name=platform[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
         gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=platformDeviceCategory[0]),
                gp.Dimension(name=platformDeviceCategory[1]),
            ],
            metrics=[
                gp.Metric(name=platformDeviceCategory[2]),
                gp.Metric(name=platformDeviceCategory[3]),
                gp.Metric(name=platformDeviceCategory[4]),
                gp.Metric(name=platformDeviceCategory[5]),
                gp.Metric(name=platformDeviceCategory[6]),
                gp.Metric(name=platformDeviceCategory[7]),
                gp.Metric(name=platformDeviceCategory[8]),
                gp.Metric(name=platformDeviceCategory[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=screenResolution[0]),
                gp.Dimension(name=screenResolution[1]),
            ],
            metrics=[
                gp.Metric(name=screenResolution[2]),
                gp.Metric(name=screenResolution[3]),
                gp.Metric(name=screenResolution[4]),
                gp.Metric(name=screenResolution[5]),
                gp.Metric(name=screenResolution[6]),
                gp.Metric(name=screenResolution[7]),
                gp.Metric(name=screenResolution[8]),
                gp.Metric(name=screenResolution[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
# Batch 4 - Request
batch_report_request4 = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=firstUserDefaultChannelGroup[0]),
                gp.Dimension(name=firstUserDefaultChannelGroup[1]),
            ],
            metrics=[
                gp.Metric(name=firstUserDefaultChannelGroup[2]),
                gp.Metric(name=firstUserDefaultChannelGroup[3]),
                gp.Metric(name=firstUserDefaultChannelGroup[4]),
                gp.Metric(name=firstUserDefaultChannelGroup[5]),
                gp.Metric(name=firstUserDefaultChannelGroup[6]),
                gp.Metric(name=firstUserDefaultChannelGroup[7]),
                gp.Metric(name=firstUserDefaultChannelGroup[8]),
                gp.Metric(name=firstUserDefaultChannelGroup[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=firstUserSource[0]),
                gp.Dimension(name=firstUserSource[1]),
            ],
            metrics=[
                gp.Metric(name=firstUserSource[2]),
                gp.Metric(name=firstUserSource[3]),
                gp.Metric(name=firstUserSource[4]),
                gp.Metric(name=firstUserSource[5]),
                gp.Metric(name=firstUserSource[6]),
                gp.Metric(name=firstUserSource[7]),
                gp.Metric(name=firstUserSource[8]),
                gp.Metric(name=firstUserSource[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=sessionDefaultChannelGroup[0]),
                gp.Dimension(name=sessionDefaultChannelGroup[1]),
            ],
            metrics=[
                gp.Metric(name=sessionDefaultChannelGroup[2]),
                gp.Metric(name=sessionDefaultChannelGroup[3]),
                gp.Metric(name=sessionDefaultChannelGroup[4]),
                gp.Metric(name=sessionDefaultChannelGroup[5]),
                gp.Metric(name=sessionDefaultChannelGroup[6]),
                gp.Metric(name=sessionDefaultChannelGroup[7]),
                gp.Metric(name=sessionDefaultChannelGroup[8]),
                gp.Metric(name=sessionDefaultChannelGroup[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
         gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=sessionSource[0]),
                gp.Dimension(name=sessionSource[1]),
            ],
            metrics=[
                gp.Metric(name=sessionSource[2]),
                gp.Metric(name=sessionSource[3]),
                gp.Metric(name=sessionSource[4]),
                gp.Metric(name=sessionSource[5]),
                gp.Metric(name=sessionSource[6]),
                gp.Metric(name=sessionSource[7]),
                gp.Metric(name=sessionSource[8]),
                gp.Metric(name=sessionSource[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %%
# Batch 5 - Request
batch_report_request5 = gp.BatchRunReportsRequest(
    property=f"properties/{property_id}",
    requests=[
      
        gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=landingPage[0]),
                gp.Dimension(name=landingPage[1]),
            ],
            metrics=[
                gp.Metric(name=landingPage[2]),
                gp.Metric(name=landingPage[3]),
                gp.Metric(name=landingPage[4]),
                gp.Metric(name=landingPage[5]),
                gp.Metric(name=landingPage[6]),
                gp.Metric(name=landingPage[7]),
                gp.Metric(name=landingPage[8]),
                gp.Metric(name=landingPage[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
           gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=eventName[0]),
                gp.Dimension(name=eventName[1]),
            ],
            metrics=[
                gp.Metric(name=eventName[2]),
                gp.Metric(name=eventName[3]),
                gp.Metric(name=eventName[4]),
                gp.Metric(name=eventName[5]),
                gp.Metric(name=eventName[6]),
                gp.Metric(name=eventName[7]),
                gp.Metric(name=eventName[8]),
                gp.Metric(name=eventName[9]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
         gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=activity[0]),
            ],
            metrics=[
                gp.Metric(name=activity[1]),
                gp.Metric(name=activity[2]),
                gp.Metric(name=activity[3]),
                gp.Metric(name=activity[4]),
                gp.Metric(name=activity[5]),
                gp.Metric(name=activity[6]),
                gp.Metric(name=activity[7]),
                gp.Metric(name=activity[8]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
          gp.RunReportRequest(
            dimensions=[
                gp.Dimension(name=loyalty[0]),
            ],
            metrics=[
                gp.Metric(name=loyalty[1]),
                gp.Metric(name=loyalty[2]),
                gp.Metric(name=loyalty[3]),
                gp.Metric(name=loyalty[4]),
                gp.Metric(name=loyalty[5]),
                gp.Metric(name=loyalty[6]),
                gp.Metric(name=loyalty[7]),
                gp.Metric(name=loyalty[8]),
            ],
            date_ranges=[gp.DateRange(start_date=start_date, end_date=end_date)]
        ),
        
    ]
)

# %% [markdown]
# Queries

# %%
# Batch 1 - Query
df1 = gp.query(service_account, batch_report_request1, report_type="batch_report")

# Batch 2 - Query
df2 = gp.query(service_account, batch_report_request2, report_type="batch_report")

# Batch 3 - Query
df3 = gp.query(service_account, batch_report_request3, report_type="batch_report")

# Batch 4 - Query
df4 = gp.query(service_account, batch_report_request4, report_type="batch_report")

# Batch 5 - Query
df5 = gp.query(service_account, batch_report_request5, report_type="batch_report")

# %% [markdown]
# Datatypes and sorting

# %%
# Convert data to datetimeobject in all dataframes

for n in range(len(df1)):
    df1[n]['date'] = pd.to_datetime(df1[n]['date'])
    
for n in range(len(df2)):
    df2[n]['date'] = pd.to_datetime(df2[n]['date'])
    
for n in range(len(df3)):
    df3[n]['date'] = pd.to_datetime(df3[n]['date'])
    
for n in range(len(df4)):
    df4[n]['date'] = pd.to_datetime(df4[n]['date'])
    
for n in range(len(df5)):
    df5[n]['date'] = pd.to_datetime(df5[n]['date'])

# %%
# Sorting of dataframes

df1[0] = df1[0].sort_values(countryID, ascending=True)
df1[1] = df1[1].sort_values(region, ascending=True)
df1[2] = df1[2].sort_values(city, ascending=True)
df1[3] = df1[3].sort_values(language, ascending=True)
df1[4] = df1[4].sort_values(userAgeBracket, ascending=True)

df2[0] = df2[0].sort_values(userGender, ascending=True)
df2[1] = df2[1].sort_values(brandingInterest, ascending=True)
df2[2] = df2[2].sort_values(browser, ascending=True)
df2[3] = df2[3].sort_values(deviceCategory, ascending=True)
df2[4] = df2[4].sort_values(mobileDeviceBranding, ascending=True)

df3[0] = df3[0].sort_values(mobileDeviceModel, ascending=True)
df3[1] = df3[1].sort_values(operatingSystem, ascending=True)
df3[2] = df3[2].sort_values(platform, ascending=True)
df3[3] = df3[3].sort_values(platformDeviceCategory, ascending=True)
df3[4] = df3[4].sort_values(screenResolution, ascending=True)

df4[0] = df4[0].sort_values(firstUserDefaultChannelGroup, ascending=True)
df4[1] = df4[1].sort_values(firstUserSource, ascending=True)
df4[2] = df4[2].sort_values(sessionDefaultChannelGroup, ascending=True)
df4[3] = df4[3].sort_values(sessionSource, ascending=True)

df5[0] = df5[0].sort_values(landingPage, ascending=True)
df5[1] = df5[1].sort_values(eventName, ascending=True)
df5[2] = df5[2].sort_values(activity, ascending=True)
df5[3] = df5[3].sort_values(loyalty, ascending=True)


#DEVICE CATEGORY, PLATFORM and PLATFORMDEVICECATEGORY not needed all 3.

# %% [markdown]
# Dataframes to .csv

# %%
csvFilePath = "output/csv/testar_"

sep = ","

def appendDFToCSV(df, csvFilePath, sep):

        if not os.path.isfile(csvFilePath):
            df.to_csv(csvFilePath, mode='a', index=0, sep=sep)
        elif len(df.columns) != len(pd.read_csv(csvFilePath, nrows=1, sep=sep).columns):
            raise Exception("Columns do not match!! Dataframe has " + str(len(df.columns)) + " columns. CSV file has " + str(len(pd.read_csv(csvFilePath, nrows=1, sep=sep).columns)) + " columns.")
        elif not (df.columns == pd.read_csv(csvFilePath, nrows=1, sep=sep).columns).all():
            raise Exception("Columns and column order of dataframe and csv file do not match!!")
        else:
            df.to_csv(csvFilePath, mode='a', index=0, sep=sep, header=False)


for n in range(len(df1)):
    appendDFToCSV(df1[n], csvFilePath + "df1_" + str(n) + ".csv", sep)
    
for n in range(len(df2)):
    appendDFToCSV(df2[n], csvFilePath + "df2_" + str(n) + ".csv", sep)
    
for n in range(len(df3)):
    appendDFToCSV(df3[n], csvFilePath + "df3_" + str(n) + ".csv", sep)
    
for n in range(len(df4)):
    appendDFToCSV(df4[n], csvFilePath + "df4_" + str(n) + ".csv", sep)
    
for n in range(len(df5)):
    appendDFToCSV(df5[n], csvFilePath + "df5_" + str(n) + ".csv", sep)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 17
#      13         else:
#      14             df.to_csv(csvFilePath, mode='a', index=0, sep=sep, header=False)
# ---> 17 for n in range(len(df1)):
#      18     appendDFToCSV(df1[n], csvFilePath + "df1_" + str(n) + ".csv", sep)
#      20 for n in range(len(df2)):
#
# NameError: name 'df1' is not defined

# %%
df1[0].head(100)
# Out:
#           date  countryID totalUsers newUsers activeUsers screenPageViews
# 55  2023-05-01         AE          1        0           0               0  \
# 56  2023-05-01         CH          1        1           1               6
# 57  2023-05-01         ES          1        1           1               1
# 58  2023-05-01         FR          1        1           1               1
# 30  2023-05-01         NG          2        1           2               2
# 59  2023-05-01         PT          1        1           1               1
# 17  2023-05-01         SE        113      104         107             181
# 21  2023-05-01         US          4        3           4               3
# 60  2023-05-02         DK          1        1           1               1
# 61  2023-05-02         FI          1        1           1               1
# 62  2023-05-02         HK          1        1           1               1
# 63  2023-05-02         IR          1        1           1               3
# 64  2023-05-02         NL          1        1           1               1
# 5   2023-05-02         SE        184      158         174             280
# 65  2023-05-02         US          1        1           1               4
# 66  2023-05-03         DE          1        1           1               2
# 31  2023-05-03         DK          2        2           2               2
# 67  2023-05-03         ES          1        1           1               1
# 68  2023-05-03         FI          1        1           1               1
# 69  2023-05-03         IR          1        0           1               6
# 70  2023-05-03         LU          1        1           1               1
# 32  2023-05-03         NO          2        1           2               4
# 71  2023-05-03         SA          1        1           1               1
# 7   2023-05-03         SE        178      156         167             248
# 72  2023-05-03         SG          1        0           1               1
# 33  2023-05-03         US          2        2           2               2
# 73  2023-05-04         CY          1        1           1               1
# 34  2023-05-04         DE          2        2           2               2
# 74  2023-05-04         FI          1        1           1               1
# 75  2023-05-04         GB          1        0           1               1
# 76  2023-05-04         IR          1        0           1               1
# 77  2023-05-04         NG          1        0           1               1
# 35  2023-05-04         NL          2        2           2               3
# 36  2023-05-04         NO          2        2           2               2
# 9   2023-05-04         SE        171      150         162             310
# 78  2023-05-04         TH          1        1           1               1
# 79  2023-05-05         DK          1        1           1               1
# 37  2023-05-05         GB          2        1           1               5
# 62         1               1                    133          5
# 63         1               1                    123          8
# 64         1               0                      0          3
# 5        206             114                  12085        897
# 65         2               1                     61         12
# 66         1               1                     91          6
# 31         2               2                     93          9
# 67         1               1                     81          4
# 68         1               1                     37          4
# 69         1               0                    309         16
# 70         1               0                      0          3
# 32         3               1                      0          9
# 71         1               0                      0          3
# 7        208             115                  12523        834
# 72         1               1                     52          3
# 33         2               1                      7          7
# 73         1               0                      5          4
# 34         3               1                      2          9
# 74         1               1                     14          4
# 75         1               0                      0          2
# 76         1               1                     11          3
# 77         1               1                      5          3
# 35         2               2                     22         10
# 36         2               2                    226          8
# 9        186             118                  11733        957
# 78         1               1                    388          4
# 79         1               0                     10          4
# 37         2               1                    149         14
# 80         1               0                      0          2
# 38         2               2                     36          8
# 81         1               1                    551         10
# 1        212             132                  13109        949
# 82         1               1                     45          4
# 83         1               1                    248          4
# 39         2               2                    132         12
# 84         1               1                     73         16
# 85         1               1                     26          5
# 40         2               1                      5          7
# 86         1               1                     28          4
# 14       151              72                   8496        621
# 87         1               0                      0          3
# 88         1               0                     28          1
# 89         1               1                     49          4
# 90         1               0                      0          3
# 13       159              93                   8414        638
# 91         1               1                     84          4
# 92         1               1                    132          4
# 93         1               0                      0          3
# 94         1               0                      0          3
# 95         1               0                      0          3
# 96         1               1                     48          4
# 41         2               1                     14          7
# 97         1               0                      0          3
# 98         1               0                      0          3
# 99         1               0                      0          3
# 42         2               0                      0          6
# 4        218             111                  11937        925
# 100        1               1                     81          6
# 43         2               0                      0          6
# 101        1               0                      0          3
# 102        1               1                      5          4
# 103        2               2                    145          7
# 104        1               1                     45          6
# 105        2               1                    347          8
# 106        1               0                      0          2
# 44         2               2                     88         14
# 107        1               1                     17          4
# 8        194             110                   9963        810
# 108        1               0                      0          2
# 109        1               0                      0          3
# 110        1               0                      0          3
# 111        1               0                      0          3
# 112        1               1                    149          5
# 113        1               1                     74          8
# 114        1               1                     70          4
# 115        2               0                      0          4
# 116        1               1                   1240          4
# 117        1               1                    271          7
# 118        1               0                      0          3
# 3        218             127                  11446        868
# 119        1               0                      0          2
# 120        1               0                      0          3
# 45         2               0                      0          6
# 121        1               1                    160          4
# 122        1               1                    208          4
# 123        1               1                     26         10
# 26         4               2                     93         19
# 124        1               0                      0          3
# 125        1               0                      0          3
# 126        2               0                      0          5

# %%
import matplotlib.pyplot as plt
import datetime as dt

# %%
dfTemp = dfQuery2.copy(deep=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 dfTemp = dfQuery2.copy(deep=True)
#
# NameError: name 'dfQuery2' is not defined

# %%
dfTemp = dfTemp.apply(pd.to_numeric)

# %%
dfTemp['date'] = dfQuery2['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))

# %%
# convert just columns "a" and "b"
#dfTemp[['date',	'year',	'month', 'day',	'activeUsers']] = dfTemp[['date',	'year',	'month', 'day',	'activeUsers']].apply(pd.to_numeric)

# %%
plt.bar('date','activeUsers', data=dfTemp)
plt.show()

# %%
import os  
os.makedirs('output/csv', exist_ok=True)  
dfQuery1.to_csv('output/csv/query1.csv')
